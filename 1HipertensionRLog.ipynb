# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ls
# Out:
#  El volumen de la unidad H es BlueDisk
#  El n�mero de serie del volumen es: B4B5-099C
#
#  Directorio de h:\SENATI\PlanSesion20204-1\ING-SOFT-SEMESTRE-IV\2-LP-3\ProyectoLP
#
# 07/03/2024  19:16    <DIR>          .
# 03/03/2024  10:55    <DIR>          ..
# 07/03/2024  19:32           143,173 1HipertensionRLog.ipynb
# 07/03/2024  22:19            38,409 2HipertensionRFor.ipynb
# 07/03/2024  22:19           330,826 3HipertensionRNeu.ipynb
# 07/03/2024  08:48           149,306 archive (1).zip
# 23/01/2024  15:56           680,328 Hipertension_Arterial_Mexico.csv
#                5 archivos      1,342,042 bytes
#                2 dirs  21,683,023,872 bytes libres

# %%
entrenamiento = pd.read_csv('Hipertension_Arterial_Mexico.csv')

# %%
entrenamiento.isnull()
# Out:
#       FOLIO_I   sexo   edad  concentracion_hemoglobina  temperatura_ambiente  \
# 0       False  False  False                      False                 False
# 1       False  False  False                      False                 False
# 2       False  False  False                      False                 False
# 3       False  False  False                      False                 False
# 4       False  False  False                      False                 False
# ...       ...    ...    ...                        ...                   ...
# 4358    False  False  False                      False                 False
# 4359    False  False  False                      False                 False
# 4360    False  False  False                      False                 False
# 4361    False  False  False                      False                 False
# 4362    False  False  False                      False                 False
#
#       valor_acido_urico  valor_albumina  valor_colesterol_hdl  \
# 0                 False           False                 False
# 1                 False           False                 False
# 2                 False           False                 False
# 3                 False           False                 False
# 4                 False           False                 False
# ...                 ...             ...                   ...
# 4358              False           False                 False
# 4359              False           False                 False
# 4360              False           False                 False
# 4361              False           False                 False
# 4362              False           False                 False
#
#       valor_colesterol_ldl  valor_colesterol_total  ...  segundamedicion_peso  \
# 0                    False                   False  ...                 False
# 1                    False                   False  ...                 False
# 2                    False                   False  ...                 False
# 3                    False                   False  ...                 False
# 4                    False                   False  ...                 False
# ...                    ...                     ...  ...                   ...
# 4358                 False                   False  ...                 False
# 4359                 False                   False  ...                 False
# 4360                 False                   False  ...                 False
# 4361                 False                   False  ...                 False
# 4362                 False                   False  ...                 False
#
#       segundamedicion_estatura  distancia_rodilla_talon  \
# 0                        False                    False
# 1                        False                    False
# 2                        False                    False
# 3                        False                    False
# 4                        False                    False
# ...                        ...                      ...
# 4358                     False                    False
# 4359                     False                    False
# 4360                     False                    False
# 4361                     False                    False
# 4362                     False                    False
#
#       circunferencia_de_la_pantorrilla  segundamedicion_cintura  \
# 0                                False                    False
# 1                                False                    False
# 2                                False                    False
# 3                                False                    False
# 4                                False                    False
# ...                                ...                      ...
# 4358                             False                    False
# 4359                             False                    False
# 4360                             False                    False
# 4361                             False                    False
# 4362                             False                    False
#
#       tension_arterial  sueno_horas  masa_corporal  actividad_total  \
# 0                False        False          False            False
# 1                False        False          False            False
# 2                False        False          False            False
# 3                False        False          False            False
# 4                False        False          False            False
# ...                ...          ...            ...              ...
# 4358             False        False          False            False
# 4359             False        False          False            False
# 4360             False        False          False            False
# 4361             False        False          False            False
# 4362             False        False          False            False
#
#       riesgo_hipertension
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 4358                False
# 4359                False
# 4360                False
# 4361                False
# 4362                False
#
# [4363 rows x 36 columns]

# %%
sns.heatmap(entrenamiento.isnull())
# Out:
# <Axes: >

# %%
entrenamiento.columns
# Out:
# Index(['FOLIO_I', 'sexo', 'edad', 'concentracion_hemoglobina',
#        'temperatura_ambiente', 'valor_acido_urico', 'valor_albumina',
#        'valor_colesterol_hdl', 'valor_colesterol_ldl',
#        'valor_colesterol_total', 'valor_creatina', 'resultado_glucosa',
#        'valor_insulina', 'valor_trigliceridos', 'resultado_glucosa_promedio',
#        'valor_hemoglobina_glucosilada', 'valor_ferritina', 'valor_folato',
#        'valor_homocisteina', 'valor_proteinac_reactiva', 'valor_transferrina',
#        'valor_vitamina_bdoce', 'valor_vitamina_d', 'peso', 'estatura',
#        'medida_cintura', 'segundamedicion_peso', 'segundamedicion_estatura',
#        'distancia_rodilla_talon', 'circunferencia_de_la_pantorrilla',
#        'segundamedicion_cintura', 'tension_arterial', 'sueno_horas',
#        'masa_corporal', 'actividad_total', 'riesgo_hipertension'],
#       dtype='object')

# %%
entrenamiento.drop('FOLIO_I',axis=1,inplace=True)

# %%
y=entrenamiento["riesgo_hipertension"]
X=entrenamiento.drop("riesgo_hipertension",axis=1)

# %%
X
# Out:
#       sexo  edad  concentracion_hemoglobina  temperatura_ambiente  \
# 0        2    41                       14.2                    22
# 1        2    65                       14.1                     9
# 2        2    68                       14.2                    22
# 3        1    35                       15.7                    11
# 4        2    65                       12.7                     7
# ...    ...   ...                        ...                   ...
# 4358     2    62                       14.2                    22
# 4359     1    39                       14.2                    22
# 4360     2    69                       15.9                    11
# 4361     1    67                       17.6                    14
# 4362     2    56                       14.2                    22
#
#       valor_acido_urico  valor_albumina  valor_colesterol_hdl  \
# 0                   4.8             4.0                    34
# 1                   4.4             3.8                    73
# 2                   4.8             4.0                    34
# 3                   6.5             4.1                    49
# 4                   4.2             4.2                    41
# ...                 ...             ...                   ...
# 4358                4.8             4.0                    34
# 4359                4.8             4.0                    34
# 4360                2.9             1.9                    21
# 4361                5.5             4.0                    44
# 4362                4.8             4.0                    34
#
#       valor_colesterol_ldl  valor_colesterol_total  valor_creatina  ...  \
# 0                     86.0                     139            0.58  ...
# 1                    130.0                     252            0.62  ...
# 2                     86.0                     139            0.58  ...
# 3                    107.0                     203            0.91  ...
# 4                     76.0                     145            0.71  ...
# ...                    ...                     ...             ...  ...
# 4358                  86.0                     139            0.58  ...
# 4359                  86.0                     139            0.58  ...
# 4360                  44.0                      74            0.34  ...
# 4361                  96.0                     171            0.80  ...
# 4362                  86.0                     139            0.58  ...
#
#       medida_cintura  segundamedicion_peso  segundamedicion_estatura  \
# 0                0.0                 64.70                     154.0
# 1                0.0                 96.75                     152.2
# 2                0.0                 68.70                     144.8
# 3               98.5                 64.70                     154.0
# 4                0.0                 97.15                     161.3
# ...              ...                   ...                       ...
# 4358             0.0                 64.25                     160.5
# 4359            80.0                 64.70                     154.0
# 4360             0.0                 71.20                     148.6
# 4361             0.0                 68.20                     167.7
# 4362            98.0                 64.70                     154.0
#
#       distancia_rodilla_talon  circunferencia_de_la_pantorrilla  \
# 0                        48.5                              33.5
# 1                        44.5                              41.1
# 2                        42.3                              37.8
# 3                        48.5                              33.5
# 4                        49.6                              42.0
# ...                       ...                               ...
# 4358                     51.1                              34.5
# 4359                     48.5                              33.5
# 4360                     47.2                              38.0
# 4361                     51.5                              36.5
# 4362                     48.5                              33.5
#
#       segundamedicion_cintura  tension_arterial  sueno_horas  masa_corporal  \
# 0                         0.0               107            4      32.889389
# 1                       113.7               104            2       1.000000
# 2                       103.7               105            1       1.000000
# 3                         0.0               117            5      26.265339
# 4                       118.9               123            2       1.000000
# ...                       ...               ...          ...            ...
# 4358                     77.8               125            4       1.000000
# 4359                      0.0               130            4      19.193721
# 4360                      0.0               147            4       1.000000
# 4361                     96.4               108            2       1.000000
# 4362                      0.0               100            4      25.600777
#
#       actividad_total
# 0                 120
# 1                 240
# 2                 480
# 3                 275
# 4                 255
# ...               ...
# 4358              280
# 4359              780
# 4360              300
# 4361              240
# 4362              300
#
# [4363 rows x 34 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=45)

# %%
from sklearn.linear_model import LogisticRegression

# %%
modelo = LogisticRegression()
modelo.fit(X_train,y_train)
# Out:
# c:\Users\liuph\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediccion = modelo.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print (classification_report(y_test,prediccion))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78       318
#            1       0.86      0.90      0.88       555
#
#     accuracy                           0.84       873
#    macro avg       0.84      0.82      0.83       873
# weighted avg       0.84      0.84      0.84       873

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, roc_auc_score,classification_report

# %%
print(classification_report(y_test,prediccion))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78       318
#            1       0.86      0.90      0.88       555
#
#     accuracy                           0.84       873
#    macro avg       0.84      0.82      0.83       873
# weighted avg       0.84      0.84      0.84       873

# %%
# Calcular el error cuadrático medio
mse = mean_squared_error(y_test, prediccion)

# Calcular el error absoluto medio
mae = mean_absolute_error(y_test, prediccion)

# Calcular el coeficiente de determinación (R cuadrado)
r2 = r2_score(y_test, prediccion)

# Calcular el área bajo la curva ROC
auc_roc = roc_auc_score(y_test, prediccion)

# %%
print('mse: '+str(mse),' mae: '+str(mae),' R2: '+str(r2), ' ABC: '+str(auc_roc))
# Out:
# mse: 0.15578465063001146  mae: 0.15578465063001146  R2: 0.327281998980112  ABC: 0.8217491075981641
